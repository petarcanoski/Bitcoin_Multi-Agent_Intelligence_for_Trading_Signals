# %%
import pandas as pd

from utils.apis import fetch_binance_btc

# %%
df = fetch_binance_btc('1d', 365 * 10 + 3)
df.to_parquet("../data/raw/btc_1D.parquet")

# %%
df = fetch_binance_btc('4h', 365 * 8 + 3)
df.to_parquet("../data/raw/btc_4h.parquet")

# %%
df = fetch_binance_btc('1h', 365 * 7 + 3)
df.to_parquet("../data/raw/btc_1h.parquet")

# %%
df = fetch_binance_btc('15m', 365 * 2 + 3)
df.to_parquet("../data/raw/btc_15m.parquet")
